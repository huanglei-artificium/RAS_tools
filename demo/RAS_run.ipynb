# %%
library(dplyr)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.2”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
base::source("/mnt/archgen/users/lei_huang/RAS_tools/RAS_src.R")
base::source("/mnt/archgen/users/lei_huang/RAS_tools/get.blockf.function.R")

# %%
# RAS_empirical; ascertained

position_file <- NA

frequency_files_list <- "/mnt/archgen/users/lei_huang/RAS_tools/RAS_empirical/frequency_files_list.txt"
# allowed non-frequency columns: CHR; POS; ALT; REF

pop_def_file <- "/mnt/archgen/users/lei_huang/RAS_tools/RAS_empirical/pop_def.txt"

pop_left1_str <- "HGDP01381,HGDP01382"

pop_left2_str <- NA

pop_left_fillna <- NA

pop_right1_str <- "CEU,FIN,GBR"

pop_right2_str <- "IBS,TSI"

pop_right_fillna <- NA

jackknife <- "CHR"

is_ascertained <- TRUE

asc_refpop <- "EUR5"

asc_freq_table <- "/mnt/archgen/users/lei_huang/RAS_tools/RAS_empirical/asc_freq_table.txt"

all_sites_block <- FALSE # not applied anymore

refpop_max_miss <- 0.75

refpop_remove_homo <- TRUE

asc_outgroup <- "AFR_all"

outgroup_max_hetero <- 0

outgroup_round_freq <- FALSE
# use the rounded frequency (0/1) when outgroup is involved in F-stats

# %%
f_block_table_all <- get_blockf(
    position_file,
    frequency_files_list,
    pop_def_file,
    pop_left1,
    pop_left2,
    pop_left_fillna,
    pop_right1,
    pop_right2,
    pop_right_fillna,
    jackknife,
    is_ascertained,
    asc_refpop,
    asc_freq_table,
    all_sites_block,
    refpop_max_miss,
    refpop_remove_homo,
    asc_outgroup,
    outgroup_max_hetero,
    outgroup_round_freq
)
# Out:
# Process information on customized population(s) in /mnt/archgen/users/lei_huang/RAS_tools/RAS_empirical/pop_def.txt .
#
# Customize population EUR5:
#
# EUR5: CEU, FIN, GBR, IBS, TSI.
#
# pop_left1:
#
# Input 2 valid population(s): HGDP01381, HGDP01382.
#
# pop_left2:
#
# pop_right1:
#
# Input 3 valid population(s): CEU, FIN, GBR.
#
# pop_right2:
#
# Input 2 valid population(s): IBS, TSI.

# %%
f_block_table_all
# Out:
#       min_freq max_freq block_id Nr_sites_all f
# 1     0        0.001     1        778729      -8.706937e-08
# 2     0        0.001     2        846957       9.284586e-08
# 3     0        0.001     3        699289      -1.128133e-07
# 4     0        0.001     4        695853      -8.697606e-09
# 5     0        0.001     5        641530      -1.751243e-09
# 6     0        0.001     6        588077      -1.031964e-07
# 7     0        0.001     7        564805      -2.603762e-07
# 8     0        0.001     8        544878      -4.057735e-08
# 9     0        0.001     9        434259      -2.776025e-08
# 10    0        0.001    10        466434      -5.371829e-07
# 11    0        0.001    11        478272      -2.792488e-07
# 12    0        0.001    12        458171      -2.744539e-07
# 13    0        0.001    13        342377      -1.336753e-07
# 14    0        0.001    14        314771      -1.440492e-07
# 15    0        0.001    15        285417       6.690887e-08
# ...
